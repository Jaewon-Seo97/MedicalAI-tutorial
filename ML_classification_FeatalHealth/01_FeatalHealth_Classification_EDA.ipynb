# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <a name='T'>
#
# <p style="padding: 20px;
#           background-color: lightblue;
#           font-family: computermodern;
#           color: white;
#           font-size: 300%;
#           text-align: center;
#           border-radius: 40px 20px;
#           "> Fetal Health Classification Algorithms </p>
# <p style="font-family: computermodern;
#           color: #000000;
#           font-size: 175%;
#           text-align: center;
#           ">Math & Physics Fun with Gus<br>
#             October 10, 2023 </p>
#
# ***
#
# # Fetal Health Dataset
#
# ### Abstract
#
# The primary goal of this dataset is to classify fetal health with the aim of preventing child and maternal mortality.
#
# ### Context
#
# Reducing child and maternal mortality is a crucial aspect of the United Nations' Sustainable Development Goals. By 2030, the UN aims to end preventable deaths of newborns and children under 5 years of age. Maternal mortality remains a significant concern, particularly in low-resource settings, and accounted for 295,000 deaths as of 2017.
#
# To address this, Cardiotocograms (CTGs) serve as a cost-effective means for assessing fetal health. The CTG equipment functions by emitting ultrasound pulses and reading the responses to gain insights into various parameters like fetal heart rate (FHR), fetal movements, uterine contractions, and more.
#
# ### Data Overview
#
# - **Total Records**: 2126
# - **Classes**:
#   - Normal
#   - Suspect
#   - Pathological
#
# ### Features Description
#
# | Feature                                               | Description                                          |
# |-------------------------------------------------------|------------------------------------------------------|
# | `baseline value`                                      | FHR baseline (beats per minute)                       |
# | `accelerations`                                       | Number of accelerations per second                    |
# | `fetal_movement`                                      | Number of fetal movements per second                  |
# | `uterine_contractions`                                | Number of uterine contractions per second             |
# | `light_decelerations`                                 | Number of light decelerations per second              |
# | `severe_decelerations`                                | Number of severe decelerations per second             |
# | `prolongued_decelerations`                            | Number of prolonged decelerations per second          |
# | `abnormal_short_term_variability`                     | Percentage of time with abnormal short-term variability|
# | `mean_value_of_short_term_variability`                | Mean value of short-term variability                  |
# | `percentage_of_time_with_abnormal_long_term_variability` | Percentage of time with abnormal long-term variability|
# | `mean_value_of_long_term_variability`                 | Mean value of long-term variability                   |
# | `histogram_width`                                     | Width of FHR histogram                                |
# | `histogram_min`                                       | Minimum (low frequency) of FHR histogram              |
# | `histogram_max`                                       | Maximum (high frequency) of FHR histogram             |
# | `histogram_number_of_peaks`                           | Number of histogram peaks                             |
# | `histogram_number_of_zeroes`                          | Number of histogram zeros                             |
# | `histogram_mode`                                      | Histogram mode                                        |
# | `histogram_mean`                                      | Histogram mean                                        |
# | `histogram_median`                                    | Histogram median                                      |
# | `histogram_variance`                                  | Histogram variance                                    |
# | `histogram_tendency`                                  | Histogram tendency                                    |
#
# ### Target Description
#
# - `fetal_health`: Tagged as 1 (Normal), 2 (Suspect), and 3 (Pathological)
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading data & checking sample
df = pd.read_csv("fetal_health.csv" , sep = ",")
print(f'Data shape: {df.shape}')
print(f'Features: {df.columns.to_list()}')
display(df)
# Out:
# Data shape: (2126, 22)
# Features: ['baseline value', 'accelerations', 'fetal_movement', 'uterine_contractions', 'light_decelerations', 'severe_decelerations', 'prolongued_decelerations', 'abnormal_short_term_variability', 'mean_value_of_short_term_variability', 'percentage_of_time_with_abnormal_long_term_variability', 'mean_value_of_long_term_variability', 'histogram_width', 'histogram_min', 'histogram_max', 'histogram_number_of_peaks', 'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean', 'histogram_median', 'histogram_variance', 'histogram_tendency', 'fetal_health']
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              120.0          0.000           0.000                 0.000
# 1              132.0          0.006           0.000                 0.006
# 2              133.0          0.003           0.000                 0.008
# 3              134.0          0.003           0.000                 0.008
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2113 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2113 non-null   float64
#  1   accelerations                                           2113 non-null   float64
#  2   fetal_movement                                          2113 non-null   float64
#  3   uterine_contractions                                    2113 non-null   float64
#  4   light_decelerations                                     2113 non-null   float64
#  5   severe_decelerations                                    2113 non-null   float64
#  6   prolongued_decelerations                                2113 non-null   float64
#  7   abnormal_short_term_variability                         2113 non-null   float64
# ...

# %%
X = df.drop(columns='fetal_health')
y = df['fetal_health'].astype(int) - 1

plt.figure(figsize=(12, 5))
sns.countplot(df, x="fetal_health", palette='Blues')
plt.title('Fetal Health Type Counts')
plt.xlabel('Fetal Health')
plt.grid(alpha=0.25)
plt.show()

# %% [markdown]
# # Preprocessing data
# ## Missing value & duplicate data & normalization

# %%
# Checking missing values
df.isnull().sum()   # Getting the number of missing values per column

"""
Processing for missing value
1. Removing the missing value
결측값 있는 행 제거 : df.dropna() or df.dropna(axis=0)
결측값 있는 열 제거 : df.dropna(axis=1)

2. Filling to arbitrary value
결측값을 특정 값으로 채우기 : df.fillna(특정값)
결측값을 결측값의 앞 행의 값으로 채우기 : df.fillna(method='ffill') or df.fillna(method='pad')
결측값을 결측값의 뒷 행의 값으로 채우기 : df.fillna(method='bfill') or df.fillna(method='backfill')
결측값을 각 열의 평균 값으로 채우기 : df.fillna(df.mean())
"""
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
# Removing duplicate data
print(f'N duplicate data: {df.duplicated().sum()}')
print(f'Before removing duplicate data: {df.shape}')
df.drop_duplicates(subset=None, keep='first', ignore_index=False, inplace=True)
print(f'After removing duplicate data: {df.shape}')
# Out:
# N duplicate data: 13
# Before removing duplicate data: (2126, 22)
# After removing duplicate data: (2113, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2113 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2113 non-null   float64
#  1   accelerations                                           2113 non-null   float64
#  2   fetal_movement                                          2113 non-null   float64
#  3   uterine_contractions                                    2113 non-null   float64
#  4   light_decelerations                                     2113 non-null   float64
#  5   severe_decelerations                                    2113 non-null   float64
#  6   prolongued_decelerations                                2113 non-null   float64
#  7   abnormal_short_term_variability                         2113 non-null   float64
# ...

# %%
# Checking feature-correlation map
plt.figure(figsize=(22,18))
sns.heatmap(df.corr(numeric_only=True).round(3), cmap='Blues', annot=True)
plt.show()
plt.savefig('EDA_correlation_map.jpg')

# %%
# Checking distribution of each feature values
plt.figure(figsize=(20,10))
sns.boxenplot(df, palette='Blues')
plt.xticks(rotation=90)
plt.show()
plt.savefig('EDA_Distribution_values.jpg')

# %%
# Distibution of feature vlaues per class(fetal_health)
fig, ax = plt.subplots(7, 3, figsize=(18, 35))
ax = ax.flatten()

for i, col in enumerate(df.columns[:-1]):       # df.columns[-1] = fetal_health = y
    sns.violinplot(data=df,                     # w\We can change the type of plot => ex. boxenplot
                    y=col, 
                    x='fetal_health',
                    hue='fetal_health',
                    palette='Blues',
                    ax=ax[i])
    ax[i].get_legend().remove()

plt.tight_layout()
plt.show()
plt.savefig('EDA_Distribution_values_perClass.jpg')

# %%
# Removing outlier
df_transformed = df.drop("fetal_health", axis = 1)
df_transformed.head()

print('Before removing outlier')
for column in df_transformed:
        plt.figure(figsize=(17,1))
        sns.boxplot(data = df_transformed, x = column)


for col in df_transformed:
    q1 = df_transformed[col].quantile(0.25)
    q3 = df_transformed[col].quantile(0.75)
    iqr = q3 - q1
    whisker_width = 1.5
    lower_whisker = q1 - (whisker_width * iqr)
    upper_whisker = q3 + whisker_width * iqr
    df_transformed[col] = np.where(df_transformed[col] > upper_whisker, upper_whisker, np.where(df_transformed[col] < lower_whisker, lower_whisker, df_transformed[col]))

print('After removing outlier')
for column in df_transformed:
        plt.figure(figsize=(17,1))
        sns.boxplot(data = df_transformed, x = column)
